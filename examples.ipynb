# %%
# %run charts.ipynb

# %%
show_charts('Attack','Defence','scatter')
# Out:
# Do you wish to change the colour? [y/n]: y
# Enter the color: blue

# %%
show_charts('Type 1','Stats','bar')

# %%
show_charts('Attack','Speed','hex')

# %%
show_charts('Type 1','Legendary','stacked')

# %%
show_charts('Type 1','Legendary','line')

# %%
show_charts('Attack','Defence','mdf')
# Out:
# Plot type cannot be recognized !
